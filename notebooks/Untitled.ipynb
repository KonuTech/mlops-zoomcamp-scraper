# %%
import requests
from bs4 import BeautifulSoup

# %%
url='https://www.otomoto.pl/motocykle-i-quady/honda/typ-naked?page=1'

# %%
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text, 'html.parser').
# Out:
#   Cell In[12], line 1
#     soup = BeautifulSoup(response.text, 'html.parser').
#                                                        ^
# SyntaxError: invalid syntax

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
sip1 = soup.find_all("h2")

# %%
sip1 = soup.find_all("h2")

# %%
len(sip1)
# Out:
# 35

# %%
sip1
# Out:
# [<h2 class="evg565y6 evg565y20 ooa-10p8u4x er34gjf0" data-testid="ad-title"><a href="https://www.otomoto.pl/motocykle-i-quady/oferta/honda-x11-honda-x11-ID6F6P2z.html" target="_self">Honda X11</a></h2>,
#  <h2 class="evg565y6 evg565y20 ooa-10p8u4x er34gjf0" data-testid="ad-title"><a href="https://www.otomoto.pl/motocykle-i-quady/oferta/honda-cbf-honda-hornet-cb600f-abs-ID6FyYqs.html" target="_self">Honda CBF</a></h2>,
#  <h2 class="evg565y6 evg565y20 ooa-10p8u4x er34gjf0" data-testid="ad-title"><a href="https://www.otomoto.pl/motocykle-i-quady/oferta/honda-cb-honda-cb650r-grzane-quickshifter-ID6FyRTQ.html" target="_self">Honda CB</a></h2>,
#  <h2 class="evg565y6 evg565y20 ooa-10p8u4x er34gjf0" data-testid="ad-title"><a href="https://www.otomoto.pl/motocykle-i-quady/oferta/honda-nc-750s-dct-niemcy-tylko-3530km-raty-ID6FxdIb.html" target="_self">Honda NC</a></h2>,
# ...

# %%
sip2 = soup.find_all("li", {"class", "ooa-1k7nwcr e19ivbs0"})

# %%
sip2
# Out:
# [<li class="ooa-1k7nwcr e19ivbs0">Niski przebieg</li>,
#  <li class="ooa-1k7nwcr e19ivbs0">2000</li>,
#  <li class="ooa-1k7nwcr e19ivbs0">51 000 km</li>,
#  <li class="ooa-1k7nwcr e19ivbs0">1 137 cm3</li>,
#  <li class="ooa-1k7nwcr e19ivbs0">Benzyna</li>,
#  <li class="ooa-1k7nwcr e19ivbs0">2000</li>,
#  <li class="ooa-1k7nwcr e19ivbs0">51 000 km</li>,
#  <li class="ooa-1k7nwcr e19ivbs0">1 137 cm3</li>,
#  <li class="ooa-1k7nwcr e19ivbs0">Benzyna</li>,
#  <li class="ooa-1k7nwcr e19ivbs0">Niski przebieg</li>,
#  <li class="ooa-1k7nwcr e19ivbs0">2012</li>,
#  <li class="ooa-1k7nwcr e19ivbs0">21 650 km</li>,
#  <li class="ooa-1k7nwcr e19ivbs0">600 cm3</li>,
#  <li class="ooa-1k7nwcr e19ivbs0">Benzyna</li>,
#  <li class="ooa-1k7nwcr e19ivbs0">2012</li>,
#  <li class="ooa-1k7nwcr e19ivbs0">21 650 km</li>,
#  <li class="ooa-1k7nwcr e19ivbs0">600 cm3</li>,
#  <li class="ooa-1k7nwcr e19ivbs0">Benzyna</li>,
#  <li class="ooa-1k7nwcr e19ivbs0">2019</li>,
# ...
